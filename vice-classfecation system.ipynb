# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import librosa
import scipy.stats

# %%
# Load data
df = pd.read_csv('voice.csv')

df.head()

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
x = df[['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt', 'sp.ent', 'sfm', 'mode','centroid', 'meanfun',
         'minfun', 'maxfun', 'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx']].values
y = df['label'].values

# %%
df.shape
# Out:
# (3168, 21)

# %%
df['label'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
# Correct label replacement (remove trailing space)
df['label'].replace(['female', 'male'], [0, 1], inplace=True)

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=15)

# %%
xtrain = np.asarray(xtrain).astype(np.float32)
ytrain = np.asarray(ytrain).astype(np.float32)
xtest = np.asarray(xtest).astype(np.float32)
ytest = np.asarray(ytest).astype(np.float32)

# %%
# Build the model
inputs = keras.Input(shape=(20))
x = layers.Dense(10, activation="sigmoid")(inputs) #(20 + 1)*(10)
x = layers.BatchNormalization()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)

# Model summary
model.summary()

model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
train = model.fit(xtrain,ytrain,validation_data=(xtest,ytest), epochs=100,verbose=1)
model.evaluate(xtest,ytest)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20)]              0
#
#  dense (Dense)               (None, 10)                210
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 261 (1.02 KB)
# Trainable params: 241 (964.00 Byte)
# Non-trainable params: 20 (80.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 80/80 [==============================] - 2s 6ms/step - loss: 0.7568 - accuracy: 0.6507 - val_loss: 0.6980 - val_accuracy: 0.5079
# Epoch 2/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.6319 - accuracy: 0.6815 - val_loss: 0.6919 - val_accuracy: 0.5205
# Epoch 3/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5952 - accuracy: 0.7099 - val_loss: 0.6717 - val_accuracy: 0.5252
# Epoch 4/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7261 - val_loss: 0.6151 - val_accuracy: 0.6861
# Epoch 5/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.5532 - accuracy: 0.7384 - val_loss: 0.6170 - val_accuracy: 0.6640
# Epoch 6/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5295 - accuracy: 0.7581 - val_loss: 0.6102 - val_accuracy: 0.6924
# Epoch 7/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.5115 - accuracy: 0.7715 - val_loss: 0.5979 - val_accuracy: 0.7177
# Epoch 8/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4984 - accuracy: 0.7904 - val_loss: 0.4982 - val_accuracy: 0.8139
# Epoch 9/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4855 - accuracy: 0.7968 - val_loss: 0.5059 - val_accuracy: 0.8013
# Epoch 10/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4710 - accuracy: 0.8133 - val_loss: 0.4809 - val_accuracy: 0.8186
# Epoch 11/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4564 - accuracy: 0.8161 - val_loss: 0.5314 - val_accuracy: 0.7618
# Epoch 12/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.8410 - val_loss: 0.4254 - val_accuracy: 0.8596
# Epoch 13/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.8461 - val_loss: 0.4162 - val_accuracy: 0.8707
# Epoch 14/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8670 - val_loss: 0.3942 - val_accuracy: 0.8675
# Epoch 15/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.8725 - val_loss: 0.3701 - val_accuracy: 0.8833
# Epoch 16/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3650 - accuracy: 0.8796 - val_loss: 0.3927 - val_accuracy: 0.8644
# Epoch 17/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3477 - accuracy: 0.8899 - val_loss: 0.3303 - val_accuracy: 0.8943
# Epoch 18/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3239 - accuracy: 0.8962 - val_loss: 0.3069 - val_accuracy: 0.9180
# Epoch 19/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3040 - accuracy: 0.9006 - val_loss: 0.3118 - val_accuracy: 0.9211
# Epoch 20/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2757 - accuracy: 0.9136 - val_loss: 0.4751 - val_accuracy: 0.8833
# Epoch 21/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.3434 - accuracy: 0.8796 - val_loss: 0.4404 - val_accuracy: 0.8502
# Epoch 22/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2861 - accuracy: 0.8907 - val_loss: 0.3353 - val_accuracy: 0.8407
# Epoch 23/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2472 - accuracy: 0.9183 - val_loss: 0.2410 - val_accuracy: 0.9558
# Epoch 24/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2324 - accuracy: 0.9242 - val_loss: 0.2196 - val_accuracy: 0.9590
# Epoch 25/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.9274 - val_loss: 0.2227 - val_accuracy: 0.9385
# Epoch 26/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2153 - accuracy: 0.9278 - val_loss: 0.1757 - val_accuracy: 0.9621
# Epoch 27/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1960 - accuracy: 0.9365 - val_loss: 0.1682 - val_accuracy: 0.9574
# Epoch 28/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1965 - accuracy: 0.9388 - val_loss: 0.1794 - val_accuracy: 0.9543
# Epoch 29/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1903 - accuracy: 0.9404 - val_loss: 0.1948 - val_accuracy: 0.9416
# Epoch 30/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1920 - accuracy: 0.9380 - val_loss: 0.1574 - val_accuracy: 0.9669
# Epoch 31/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1853 - accuracy: 0.9459 - val_loss: 0.1641 - val_accuracy: 0.9621
# Epoch 32/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1751 - accuracy: 0.9432 - val_loss: 0.1451 - val_accuracy: 0.9669
# Epoch 33/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1685 - accuracy: 0.9451 - val_loss: 0.1372 - val_accuracy: 0.9716
# Epoch 34/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1662 - accuracy: 0.9455 - val_loss: 0.1924 - val_accuracy: 0.9306
# Epoch 35/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1657 - accuracy: 0.9526 - val_loss: 0.2164 - val_accuracy: 0.9495
# Epoch 36/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1780 - accuracy: 0.9404 - val_loss: 0.1333 - val_accuracy: 0.9574
# Epoch 37/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1543 - accuracy: 0.9511 - val_loss: 0.1720 - val_accuracy: 0.9574
# Epoch 38/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1723 - accuracy: 0.9428 - val_loss: 0.4003 - val_accuracy: 0.9196
# Epoch 39/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2373 - accuracy: 0.9305 - val_loss: 0.3893 - val_accuracy: 0.8927
# Epoch 40/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.9365 - val_loss: 0.2580 - val_accuracy: 0.8754
# Epoch 41/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1726 - accuracy: 0.9436 - val_loss: 0.1659 - val_accuracy: 0.9495
# Epoch 42/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9479 - val_loss: 0.1150 - val_accuracy: 0.9653
# Epoch 43/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1535 - accuracy: 0.9495 - val_loss: 0.1163 - val_accuracy: 0.9700
# Epoch 44/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1512 - accuracy: 0.9515 - val_loss: 0.1140 - val_accuracy: 0.9700
# Epoch 45/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9554 - val_loss: 0.1557 - val_accuracy: 0.9353
# Epoch 46/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1498 - accuracy: 0.9507 - val_loss: 0.1496 - val_accuracy: 0.9432
# Epoch 47/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.9542 - val_loss: 0.1055 - val_accuracy: 0.9716
# Epoch 48/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9526 - val_loss: 0.1640 - val_accuracy: 0.9432
# Epoch 49/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9471 - val_loss: 0.1033 - val_accuracy: 0.9732
# Epoch 50/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1470 - accuracy: 0.9519 - val_loss: 0.1396 - val_accuracy: 0.9621
# Epoch 51/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1490 - accuracy: 0.9534 - val_loss: 0.1026 - val_accuracy: 0.9748
# Epoch 52/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1344 - accuracy: 0.9574 - val_loss: 0.1250 - val_accuracy: 0.9606
# Epoch 53/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.9530 - val_loss: 0.1058 - val_accuracy: 0.9685
# Epoch 54/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1408 - accuracy: 0.9558 - val_loss: 0.1273 - val_accuracy: 0.9637
# Epoch 55/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1384 - accuracy: 0.9542 - val_loss: 0.1005 - val_accuracy: 0.9637
# Epoch 56/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1449 - accuracy: 0.9558 - val_loss: 0.1312 - val_accuracy: 0.9495
# Epoch 57/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1334 - accuracy: 0.9546 - val_loss: 0.1290 - val_accuracy: 0.9606
# Epoch 58/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.9574 - val_loss: 0.0999 - val_accuracy: 0.9669
# Epoch 59/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1264 - accuracy: 0.9570 - val_loss: 0.1855 - val_accuracy: 0.9464
# Epoch 60/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1343 - accuracy: 0.9538 - val_loss: 0.1399 - val_accuracy: 0.9716
# Epoch 61/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1329 - accuracy: 0.9566 - val_loss: 0.1136 - val_accuracy: 0.9653
# Epoch 62/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9582 - val_loss: 0.0995 - val_accuracy: 0.9732
# Epoch 63/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1358 - accuracy: 0.9590 - val_loss: 0.1053 - val_accuracy: 0.9685
# Epoch 64/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9597 - val_loss: 0.1324 - val_accuracy: 0.9637
# Epoch 65/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9558 - val_loss: 0.1265 - val_accuracy: 0.9685
# Epoch 66/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.9609 - val_loss: 0.0997 - val_accuracy: 0.9685
# Epoch 67/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1316 - accuracy: 0.9570 - val_loss: 0.1345 - val_accuracy: 0.9464
# Epoch 68/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9550 - val_loss: 0.1046 - val_accuracy: 0.9732
# Epoch 69/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1252 - accuracy: 0.9566 - val_loss: 0.0945 - val_accuracy: 0.9732
# Epoch 70/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1275 - accuracy: 0.9597 - val_loss: 0.0904 - val_accuracy: 0.9732
# Epoch 71/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.9609 - val_loss: 0.1044 - val_accuracy: 0.9669
# Epoch 72/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1314 - accuracy: 0.9570 - val_loss: 0.1051 - val_accuracy: 0.9653
# Epoch 73/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9594 - val_loss: 0.0925 - val_accuracy: 0.9700
# Epoch 74/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1219 - accuracy: 0.9601 - val_loss: 0.1112 - val_accuracy: 0.9700
# Epoch 75/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1329 - accuracy: 0.9605 - val_loss: 0.0901 - val_accuracy: 0.9700
# Epoch 76/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1349 - accuracy: 0.9546 - val_loss: 0.0850 - val_accuracy: 0.9732
# Epoch 77/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1254 - accuracy: 0.9594 - val_loss: 0.0951 - val_accuracy: 0.9669
# Epoch 78/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9625 - val_loss: 0.1021 - val_accuracy: 0.9637
# Epoch 79/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1194 - accuracy: 0.9625 - val_loss: 0.1122 - val_accuracy: 0.9511
# Epoch 80/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9530 - val_loss: 0.1074 - val_accuracy: 0.9653
# Epoch 81/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9586 - val_loss: 0.1133 - val_accuracy: 0.9653
# Epoch 82/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9645 - val_loss: 0.0902 - val_accuracy: 0.9732
# Epoch 83/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.9578 - val_loss: 0.0924 - val_accuracy: 0.9716
# Epoch 84/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9566 - val_loss: 0.0929 - val_accuracy: 0.9700
# Epoch 85/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.9601 - val_loss: 0.1198 - val_accuracy: 0.9716
# Epoch 86/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9511 - val_loss: 0.1013 - val_accuracy: 0.9732
# Epoch 87/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1310 - accuracy: 0.9574 - val_loss: 0.1018 - val_accuracy: 0.9685
# Epoch 88/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1249 - accuracy: 0.9605 - val_loss: 0.1044 - val_accuracy: 0.9637
# Epoch 89/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1271 - accuracy: 0.9609 - val_loss: 0.0919 - val_accuracy: 0.9732
# Epoch 90/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.9605 - val_loss: 0.1054 - val_accuracy: 0.9653
# Epoch 91/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1173 - accuracy: 0.9617 - val_loss: 0.1084 - val_accuracy: 0.9495
# Epoch 92/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1377 - accuracy: 0.9519 - val_loss: 0.0885 - val_accuracy: 0.9748
# Epoch 93/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1190 - accuracy: 0.9645 - val_loss: 0.0980 - val_accuracy: 0.9637
# Epoch 94/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1249 - accuracy: 0.9590 - val_loss: 0.0876 - val_accuracy: 0.9700
# Epoch 95/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1232 - accuracy: 0.9578 - val_loss: 0.0838 - val_accuracy: 0.9716
# Epoch 96/100
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1231 - accuracy: 0.9597 - val_loss: 0.0950 - val_accuracy: 0.9700
# Epoch 97/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1268 - accuracy: 0.9605 - val_loss: 0.0924 - val_accuracy: 0.9700
# Epoch 98/100
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9582 - val_loss: 0.0886 - val_accuracy: 0.9716
# Epoch 99/100
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.9601 - val_loss: 0.0900 - val_accuracy: 0.9732
# Epoch 100/100
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9621 - val_loss: 0.0986 - val_accuracy: 0.9669
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9669
# [0.09860359132289886, 0.9668769836425781]

# %%
def plot_scores(train) :
    accuracy = train.history['accuracy']
    val_accuracy = train.history['val_accuracy']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Train accuracy')
    plt.plot(epochs, val_accuracy, 'r', label='Test validation')
    # plt.hlines(0.95,0,50)
    plt.title('Scores')
    plt.legend()
    plt.show()

plot_scores(train)
# Out:
# 20/20 [==============================] - 0s 2ms/step

# %%
model.save('ML.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import scipy.stats
import librosa
import numpy as np

def extract_features(audio_path):
    y, sr = librosa.load(audio_path)
    S = np.abs(librosa.stft(y))
    centroid = librosa.feature.spectral_centroid(S=S)[0]

    features = {}

    features['meanfreq'] = np.mean(centroid) / 1000
    features['sd'] = np.std(centroid) / 1000
    features['median'] = np.median(centroid) / 1000
    features['Q25'] = np.percentile(centroid, 25) / 1000
    features['Q75'] = np.percentile(centroid, 75) / 1000
    features['IQR'] = features['Q75'] - features['Q25']
    features['skew'] = scipy.stats.skew(centroid)
    features['kurt'] = scipy.stats.kurtosis(centroid)
    features['sp.ent'] = scipy.stats.entropy(S.flatten())
    features['sfm'] = np.mean(librosa.feature.spectral_flatness(S=S))

    mode_result = scipy.stats.mode(centroid)
    mode_value = np.atleast_1d(mode_result.mode)[0]
    features['mode'] = mode_value / 1000

    features['centroid'] = np.mean(centroid) / 1000


    yin_values = librosa.yin(y, fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7'))
    features['meanfun'] = np.mean(yin_values) / 1000
    features['minfun'] = np.min(yin_values) / 1000
    features['maxfun'] = np.max(yin_values) / 1000

    tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
    features['meandom'] = np.mean(tonnetz)
    features['mindom'] = np.min(tonnetz)
    features['maxdom'] = np.max(tonnetz)
    features['dfrange'] = features['maxdom'] - features['mindom']
    features['modindx'] = np.mean(np.abs(np.diff(yin_values))) / (features['maxfun'] - features['minfun'])

    return features

audio = '/content/girl.mpga'

f = extract_features(audio)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model('ML.h5')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20)]              0
#
#  dense (Dense)               (None, 10)                210
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 261 (1.02 KB)
# Trainable params: 241 (964.00 Byte)
# Non-trainable params: 20 (80.00 Byte)
# _________________________________________________________________

# %%
key = ['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt', 'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun',
         'minfun', 'maxfun', 'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx']
data = []
for i in key:
  data.append(f[i])
# Out:
# 0.6538670203901099
# 1.3650264082363706
# 0.0
# 0.0
# 0.5602073376021549
# 0.5602073376021549
# 2.6090725726631727
# 6.5149287431774106
# 8.230271
# 0.68396854
# 0.0
# 0.6538670203901099
# 1.6382156726687083
# 0.06523668639053254
# 2.205
# 0.0004798874430862082
# -0.3149681202161071
# 0.4467667341232298
# 0.761734854339337
# 21.248333969985506

# %%
xtest.shape
# Out:
# (634, 20)

# %%
data = np.array(data)
data.shape
# Out:
# (20,)

# %%
data = data.reshape((1,20))

# %%
model.evaluate(xtest,ytest)
# Out:
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9669
# [0.09860359132289886, 0.9668769836425781]

# %%
pre = model.predict(data)
pre
# Out:
# 1/1 [==============================] - 0s 71ms/step
# array([[0.00045873]], dtype=float32)

# %%
float_str = str(pre)
decimal_pos = float_str.find('.')
last = float_str[2]
b = int(last)
print('.....value <= 5 : female vice')
print('.....value > 5 : male vice')
if b >= 5:
  print(last,':male vice')
else:
  print(last,'female vice')
# Out:
# .....value <= 5 : female vice
# .....value > 5 : male vice
# 0 female vice

# %%
import IPython.display as ipd

# %%
ipd.Audio(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt

# Define data
days = list(range(1, 16))  # Days 1 to 15
tasks = [
    "Data Collection",
    "Data Cleaning",
    "Feature Extraction",
    "Model Architecture Design",
    "Model Implementation",
    "Model Training",
    "Model Evaluation",
    "Hyperparameter Tuning",
    "Model Retraining",
    "Final Evaluation",
    "Result Analysis",
    "Graph Plotting",
    "Documentation",
    "Presentation Preparation",
    "Final Review"
]

# Create the plot
plt.figure(figsize=(10, 8))
plt.plot(days, tasks, marker='o', linestyle='-', color='b')

# Customize the plot
plt.xlabel('Day')
plt.ylabel('Task')
plt.title('Project Progress Over 15 Days')
plt.yticks(ticks=range(15), labels=tasks)
plt.xticks(ticks=range(1, 16))

# Add grid for better readability
plt.grid(True)

# Display the plot
plt.gca().invert_yaxis()  # Invert y-axis to show tasks from top to bottom
plt.tight_layout()
plt.show()
